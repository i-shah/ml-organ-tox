# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext sql 
# %pylab inline
# %matplotlib inline
import pylab as pl
import pandas as pd
import os, random

import pickle,time

tmstmp = time.strftime("%m-%d-%Y",time.localtime())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Initialisation

# %%
# Set up the local source files
TOP = os.getcwd().replace('notebooks','')
LIB = TOP+'lib'
if not LIB in sys.path: sys.path.append(LIB)

DAT_DIR = TOP + 'data/'
RES_DIR = TOP + 'results/'
FIG_DIR = TOP + 'figs/'

from organtox import *

DB = openMongo(host='pb.epa.gov',user='devel',passwd='devel',db='organtox_v1')
DB.collection_names()
# Out:
# [u'chm_fp', u'ml_lr_v1', u'bio_fp', u'ml_summary_v1', u'ml_run_v1', u'tox_fp']

# %%
Outcomes =[u'CHR:Adrenal Gland',
 u'CHR:Bone Marrow',
 u'CHR:Brain',
 u'CHR:Eye',
 u'CHR:Heart',
 u'CHR:Kidney',
 u'CHR:Liver',
 u'CHR:Lung',
 u'CHR:Lymph Node',
 u'CHR:Mammary Gland',
 u'CHR:Pancreas',
 u'CHR:Pituitary Gland',
 u'CHR:Spleen',
 u'CHR:Stomach',
 u'CHR:Testes',
 u'CHR:Thymus',
 u'CHR:Thyroid Gland',
 u'CHR:Urinary Bladder',
 u'CHR:Uterus',
 u'MGR:Brain',
 u'MGR:Kidney',
 u'MGR:Ovary',
 u'MGR:Testes',
 u'SUB:Adrenal Gland',
 u'SUB:Bone Marrow',
 u'SUB:Brain',
 u'SUB:Heart',
 u'SUB:Kidney',
 u'SUB:Liver',
 u'SUB:Lung',
 u'SUB:Spleen',
 u'SUB:Stomach',
 u'SUB:Testes',
 u'SUB:Thymus',
 u'SUB:Thyroid Gland']
len(Outcomes)
# Out:
# 35

# %% [markdown]
# ## Figure 1. Number of positive and negative examples

# %% [markdown]
# ### Count the target organs across all studies

# %%
Res = []
TOX = DB.tox_fp.distinct('tox_fpp1.ds')
for tox in TOX:
    n_p,n_n = DB.tox_fp.find({'tox_fpp1.ds':tox}).count(),DB.tox_fp.find({'tox_fpn1.ds':tox}).count()
    s,o=tox.split(':')
    Res.append(dict(study=s,organ=o,val_of='pos',n=n_p))
    Res.append(dict(study=s,organ=o,val_of='neg',n=n_n))
DS_n = pd.pivot_table(pd.DataFrame(Res),index='organ',columns=['study','val_of'],values='n')
DS_n.fillna(0,inplace=True)
DS_n.sort(columns=('CHR','pos'),ascending=True,inplace=True)

# %%
import pylab as pl
fig = pl.figure(figsize=(16,9))
STUDIES=[u'CHR',u'SUB', 'MGR','DEV']
k=0
for s in STUDIES:
    k+=1
    ax=pl.subplot(1,len(STUDIES),k)
    ax.vlines(50,-1,DS_n.shape[0],linestyles='-',lw=0.2)
    DS_n[s][['pos','neg']].ix[:60].plot.barh(stacked=True,legend=False,ax=ax,lw=0, color=['red','green'])
    ax.set_title(s,fontdict=dict(size=20))
    frame1 = plt.gca()
    if k>1: 
        for ylab in ax.get_yticklabels():ylab.set_visible(False)
    for xlab in ax.get_xticklabels():xlab.set_rotation(90)
    ax.set_xlim(0,700)
    ax.set_ylabel('')
    #ax.set_ylim(0,600)
    ax.grid(True)
    ax.set_xlim(0,600)
    ax.set_xlabel('No. of chemicals')
ax.legend(loc=4)
fig.savefig(FIG_DIR+'Figure-1.png')
fig.savefig(FIG_DIR+'Figure-1.svg')

# %% [markdown]
# ## Figure 2. F1 Score and No of Descriptors

# %%
# What are the top classifiers ?

X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},'pt':'cvt','n_obs':100,'n_ds':{'$lt':25}},
                                                dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
#for (pred,dt),P_i in X.groupby(['pred','dt_in']):
for (pred),P_i in X.groupby(['pred']):
    Res = pd.concat((Res,P_i.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf1 = Res.reset_index(drop=True)
Perf1['organ']=Perf1.pred.apply(lambda x:x.split(":")[1])
Perf1['study']=Perf1.pred.apply(lambda x:x.split(":")[0])

# %%
print 'F1', Perf1.f1_mn.mean(),Perf1.f1_mn.std(),Perf1.f1_mn.quantile(q=0.05),Perf1.f1_mn.quantile(q=0.95),\
      np.sqrt((Perf1.f1_sd**2).sum()/Perf1.f1_sd.shape[0])
print 'Sens', Perf1.sens_mn.mean(),Perf1.sens_mn.quantile(q=0.05),Perf1.sens_mn.quantile(q=0.95),\
      np.sqrt((Perf1.sens_sd**2).sum()/Perf1.sens_sd.shape[0])
print 'Spec', Perf1.spec_mn.mean(),Perf1.spec_mn.quantile(q=0.05),Perf1.spec_mn.quantile(q=0.95),\
      np.sqrt((Perf1.spec_sd**2).sum()/Perf1.spec_sd.shape[0])

LR = pd.DataFrame(Perf1.lr.value_counts())
LR['pct']=100*LR.lr/Perf1.shape[0]
print 'LR',LR.round()
DT = pd.DataFrame(Perf1.dt_in.value_counts())
DT['pct']=100*DT.dt_in/Perf1.shape[0]
print 'DT',DT.round()
print Perf1.n_ds.hist()
# Out:
# F1 0.756544281118 0.0477848713734 0.686516321493 0.838412253321 0.085644646674
# Sens 0.842021575752 0.769060328061 0.900040285205 0.126279903634
# Spec 0.703251079615 0.609845481405 0.928432562538 0.0827035758773
# LR        lr   pct
# KNN0   29  83.0
# SVCR0   6  17.0
# DT      dt_in   pct
# bio     10  29.0
# bct     10  29.0
# bc       8  23.0
# ct       7  20.0
# Axes(0.125,0.125;0.775x0.775)

# %%
Perf1['clf_id']=Perf1.apply(lambda x: "%s:%d/%s/%s:%d" % (x['pred'],x['n_obs'],x['lr'],x['dt_in'],x['n_ds']),axis=1)
Perf2 = Perf1.set_index(['clf_id','pred','lr','dt_in','n_ds','n_obs'])
Perf2.sort(columns=['f1_mn','sens_mn','spec_mn'],ascending=False,inplace=True)
#Perf2[['f1_mn','f1_sd','sens_mn','sens_sd','spec_mn','spec_sd']].to_excel(DAT_DIR+'Table-1-cvt.xlsx')

# %%
# Relationship with n_obs

import statsmodels.api as sm
def mySmooth(x1,y1):
    return sm.nonparametric.lowess(y1,x1,return_sorted=False,it=3,delta=0.4)

fig = pl.figure(figsize=(25,30))
i=0
for clf_id,pred,lr,dt_in,n_ds,n_obs in list(Perf2.index):
    i+=1
    #if i>5: break
    print pred,lr
    X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':pred,'pt':'cvt',
                                                 'lr':lr,
                                                 'n_obs':n_obs,'dt_in':dt_in},
                                                 dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

    ax = pl.subplot(10,5,i)
    ax.plot(X.n_ds,X.f1_mn)
    ax.plot(X.n_ds,mySmooth(X.n_ds,X.f1_mn),ls='--',lw=2,color='grey')
    ax.fill_between(X.n_ds,X.f1_mn-X.f1_sd,X.f1_mn+X.f1_sd,color='grey',alpha=0.2)
    ax.set_ylim(0.5,1)
    ax.grid('on')
    ax.set_title(clf_id,fontdict=dict(size=14))
    ax.set_xlabel('No. of descriptors')
    ax.set_ylabel('F1 score')
    y=X.query('n_ds==%d'%n_ds).f1_mn
    x1,x2=X.n_ds.min(),X.n_ds.max()
    ax.hlines(y,x1,x2,colors='red')
    ax.vlines(n_ds,0.5,1,colors='red')
    ax.text(n_ds+1,y+0.04,"(%d,%3.2f)" % (n_ds,y),color='red',fontdict=dict(size=10))

pl.subplots_adjust(wspace=0.4,hspace=0.4,top=0.9,bottom=0.1)
fig.savefig(FIG_DIR+'Figure-2.png')
fig.savefig(FIG_DIR+'Figure-2.svg')
# Out:
# MGR:Brain SVCR0
# CHR:Urinary Bladder SVCR0
# CHR:Mammary Gland SVCR0
# CHR:Pancreas KNN0
# SUB:Bone Marrow KNN0
# CHR:Lymph Node KNN0
# MGR:Ovary KNN0
# CHR:Thymus KNN0
# CHR:Bone Marrow KNN0
# CHR:Uterus KNN0
# SUB:Lung KNN0
# MGR:Testes KNN0
# SUB:Stomach KNN0
# CHR:Pituitary Gland KNN0
# SUB:Thyroid Gland KNN0
# CHR:Eye KNN0
# SUB:Thymus KNN0
# SUB:Adrenal Gland KNN0
# CHR:Heart KNN0
# SUB:Brain KNN0
# SUB:Heart KNN0
# CHR:Liver SVCR0
# CHR:Stomach KNN0
# SUB:Testes KNN0
# MGR:Kidney KNN0
# SUB:Liver SVCR0
# CHR:Brain KNN0
# CHR:Thyroid Gland KNN0
# SUB:Spleen KNN0
# CHR:Lung KNN0
# CHR:Testes KNN0
# CHR:Adrenal Gland KNN0
# CHR:Kidney SVCR0
# CHR:Spleen KNN0
# SUB:Kidney KNN0

# %%
# Results: Machine Learning 

# What are the top classifiers ?

X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},'pt':'cvt','n_ds':{'$lt':25},'n_obs':100},
                                             dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
#for (pred,dt),P_i in X.groupby(['pred','dt_in']):
for (pred),P_i in X.groupby(['pred']):
    Res = pd.concat((Res,P_i.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf1 = Res.reset_index(drop=True)

# %%
print 'F1', Perf1.f1_mn.mean(),Perf1.f1_mn.std(),Perf1.f1_mn.quantile(q=0.05),Perf1.f1_mn.quantile(q=0.95),\
      np.sqrt((Perf1.f1_sd**2).sum()/Perf1.f1_sd.shape[0])
print 'Sens', Perf1.sens_mn.mean(),Perf1.sens_mn.quantile(q=0.05),Perf1.sens_mn.quantile(q=0.95),\
      np.sqrt((Perf1.sens_sd**2).sum()/Perf1.sens_sd.shape[0])
print 'Spec', Perf1.spec_mn.mean(),Perf1.spec_mn.quantile(q=0.05),Perf1.spec_mn.quantile(q=0.95),\
      np.sqrt((Perf1.spec_sd**2).sum()/Perf1.spec_sd.shape[0])

LR = pd.DataFrame(Perf1.lr.value_counts())
LR['pct']=100*LR.lr/Perf1.shape[0]
print 'LR',LR.round()
DT = pd.DataFrame(Perf1.dt_in.value_counts())
DT['pct']=100*DT.dt_in/Perf1.shape[0]
print 'DT',DT.round()
print Perf1.n_ds.hist()
# Out:
# F1 0.756544281118 0.0477848713734 0.686516321493 0.838412253321 0.085644646674
# Sens 0.842021575752 0.769060328061 0.900040285205 0.126279903634
# Spec 0.703251079615 0.609845481405 0.928432562538 0.0827035758773
# LR        lr   pct
# KNN0   29  83.0
# SVCR0   6  17.0
# DT      dt_in   pct
# bio     10  29.0
# bct     10  29.0
# bc       8  23.0
# ct       7  20.0
# Axes(0.125,0.125;0.775x0.775)

# %% [markdown]
# ## Table 1. Optimal Classifiers / 100

# %%
# What are the top classifiers by pred, dt and ?
X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},
                                             'pt':'cvt','n_obs':100,'n_ds':{'$lt':25}},
                                                dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
for (pred),P_i in X.groupby(['pred']):
    for (dt), P_ij in P_i.groupby(['dt_in']):
        for (lr),P_ijk in P_ij.groupby(['lr']):
            Res = pd.concat((Res,P_ijk.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf1 = Res.reset_index(drop=True)




Perf1['res2']=Perf1.apply(lambda x: "%s:%d/%s/%s:%d" % (x.pred,x.n_obs,x.lr,x.dt_in,x.n_ds),axis=1)
Perf1['res2_f1']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.f1_mn,x.f1_sd),axis=1)
Perf1['res2_sn']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.sens_mn,x.sens_sd),axis=1)
Perf1['res2_sp']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.spec_mn,x.spec_sd),axis=1)

P1 = None
for p in Perf1.pred.unique():
    P1 = pd.concat((P1,Perf1.query("pred=='%s'" % p).sort('f1_mn',ascending=False).head(1)))

# %%
P1.head()
# Out:
#        acc_mn    acc_sd   bacc_mn   bacc_sd dt_in     f1_mn     f1_sd    lr  \
# 18   0.649505  0.099312  0.707124  0.098002   bio  0.692457  0.097200  KNN0
# 50   0.716796  0.087636  0.800728  0.073463   bct  0.787910  0.073129  KNN0
# 114  0.634756  0.092942  0.740913  0.085071    ct  0.715611  0.083533  KNN0
# 122  0.702385  0.090102  0.777526  0.081810    bc  0.766621  0.081641  KNN0
# 170  0.704327  0.096484  0.761763  0.089683   bct  0.751223  0.090594  KNN0
#
#      n_ds  n_obs               pred   sens_mn   sens_sd   spec_mn   spec_sd  \
# 18     23    100  CHR:Adrenal Gland  0.769158  0.146680  0.645089  0.096149
# 50     24    100    CHR:Bone Marrow  0.885475  0.104164  0.715981  0.074972
# 114    24    100          CHR:Brain  0.859999  0.132434  0.621828  0.079689
# 122    21    100            CHR:Eye  0.837915  0.124067  0.717138  0.080726
# 170    21    100          CHR:Heart  0.807889  0.127729  0.715638  0.093209
#
#                                   res2    res2_f1    res2_sn    res2_sp
# 18   CHR:Adrenal Gland:100/KNN0/bio:23  0.69±0.10  0.77±0.15  0.65±0.10
# 50     CHR:Bone Marrow:100/KNN0/bct:24  0.79±0.07  0.89±0.10  0.72±0.07
# 114           CHR:Brain:100/KNN0/ct:24  0.72±0.08  0.86±0.13  0.62±0.08
# 122             CHR:Eye:100/KNN0/bc:21  0.77±0.08  0.84±0.12  0.72±0.08
# 170          CHR:Heart:100/KNN0/bct:21  0.75±0.09  0.81±0.13  0.72±0.09

# %%
P1.f1_mn.mean()
# Out:
# 0.7565442811183286

# %%
LR = pd.DataFrame(P1.lr.value_counts())
LR['pct']=100*LR.lr/P1.shape[0]
print 'LR',LR.round()
print

DT = pd.DataFrame(P1.dt_in.value_counts())
DT['pct']=100*DT.dt_in/P1.shape[0]
print 'DT',DT.round()
# Out:
# LR        lr   pct
# KNN0   29  83.0
# SVCR0   6  17.0
#
# DT      dt_in   pct
# bio     10  29.0
# bct     10  29.0
# bc       8  23.0
# ct       7  20.0

# %%
##Table 1
#P1.sort('f1_mn',ascending=False)[['res2','pred','lr','dt_in','n_ds','res2_f1','res2_sn','res2_sp']].to_csv(DAT_DIR+'table-1_2.csv')
Table1 = P1.sort('f1_mn',ascending=False)[['res2','pred','lr','dt_in','n_ds','res2_f1','res2_sn','res2_sp']]
Table1.columns=['Classifier id','Organ Toxicity','Algorithm','dt','n_ds','F1 Score','Sensitivity','Specificity']
#Table1.to_excel(DAT_DIR+'Table-1.xlsx',encoding='utf8')
Table1
# Out:
#                              Classifier id       Organ Toxicity Algorithm  \
# 783             MGR:Brain:100/SVCR0/bio:24            MGR:Brain     SVCR0
# 695   CHR:Urinary Bladder:100/SVCR0/bct:24  CHR:Urinary Bladder     SVCR0
# 367      CHR:Mammary Gland:100/SVCR0/bc:24    CHR:Mammary Gland     SVCR0
# 402            CHR:Pancreas:100/KNN0/bc:22         CHR:Pancreas      KNN0
# 970        SUB:Bone Marrow:100/KNN0/bct:13      SUB:Bone Marrow      KNN0
# 330         CHR:Lymph Node:100/KNN0/bct:24       CHR:Lymph Node      KNN0
# 842               MGR:Ovary:100/KNN0/bc:24            MGR:Ovary      KNN0
# 602              CHR:Thymus:100/KNN0/bc:22           CHR:Thymus      KNN0
# 50         CHR:Bone Marrow:100/KNN0/bct:24      CHR:Bone Marrow      KNN0
# 730             CHR:Uterus:100/KNN0/bct:23           CHR:Uterus      KNN0
# 1194               SUB:Lung:100/KNN0/ct:23             SUB:Lung      KNN0
# 890             MGR:Testes:100/KNN0/bct:24           MGR:Testes      KNN0
# 1274            SUB:Stomach:100/KNN0/ct:22          SUB:Stomach      KNN0
# 458    CHR:Pituitary Gland:100/KNN0/bio:24  CHR:Pituitary Gland      KNN0
# 1378     SUB:Thyroid Gland:100/KNN0/bio:22    SUB:Thyroid Gland      KNN0
# 122                 CHR:Eye:100/KNN0/bc:21              CHR:Eye      KNN0
# 1338            SUB:Thymus:100/KNN0/bio:22           SUB:Thymus      KNN0
# 922       SUB:Adrenal Gland:100/KNN0/bc:22    SUB:Adrenal Gland      KNN0
# 170              CHR:Heart:100/KNN0/bct:21            CHR:Heart      KNN0
# 1018             SUB:Brain:100/KNN0/bio:24            SUB:Brain      KNN0
# 1042              SUB:Heart:100/KNN0/bc:22            SUB:Heart      KNN0
# 263             CHR:Liver:100/SVCR0/bio:23            CHR:Liver     SVCR0
# 530            CHR:Stomach:100/KNN0/bct:23          CHR:Stomach      KNN0
# 1282             SUB:Testes:100/KNN0/bc:23           SUB:Testes      KNN0
# 834              MGR:Kidney:100/KNN0/ct:22           MGR:Kidney      KNN0
# 1135            SUB:Liver:100/SVCR0/bct:24            SUB:Liver     SVCR0
# 114               CHR:Brain:100/KNN0/ct:24            CHR:Brain      KNN0
# 674       CHR:Thyroid Gland:100/KNN0/ct:23    CHR:Thyroid Gland      KNN0
# 1218            SUB:Spleen:100/KNN0/bio:24           SUB:Spleen      KNN0
# 290               CHR:Lung:100/KNN0/bct:19             CHR:Lung      KNN0
# 594              CHR:Testes:100/KNN0/ct:22           CHR:Testes      KNN0
# 18       CHR:Adrenal Gland:100/KNN0/bio:23    CHR:Adrenal Gland      KNN0
# 223            CHR:Kidney:100/SVCR0/bio:24           CHR:Kidney     SVCR0
# 514              CHR:Spleen:100/KNN0/ct:23           CHR:Spleen      KNN0
# 1098            SUB:Kidney:100/KNN0/bio:20           SUB:Kidney      KNN0
#
#        dt  n_ds   F1 Score Sensitivity Specificity
# 783   bio    24  0.85±0.09   0.79±0.13   0.95±0.06
# 695   bct    24  0.85±0.09   0.80±0.13   0.93±0.07
# 367    bc    24  0.83±0.10   0.77±0.14   0.93±0.07
# 402    bc    22  0.81±0.07   0.89±0.10   0.75±0.07
# 970   bct    13  0.81±0.07   0.90±0.10   0.74±0.07
# 330   bct    24  0.81±0.07   0.89±0.10   0.74±0.07
# 842    bc    24  0.81±0.08   0.87±0.11   0.75±0.07
# 602    bc    22  0.80±0.08   0.87±0.11   0.75±0.08
# 50    bct    24  0.79±0.07   0.89±0.10   0.72±0.07
# 730   bct    23  0.79±0.08   0.86±0.12   0.73±0.08
# 1194   ct    23  0.78±0.07   0.91±0.10   0.69±0.07
# 890   bct    24  0.78±0.08   0.86±0.12   0.72±0.08
# 1274   ct    22  0.78±0.07   0.90±0.11   0.69±0.07
# 458   bio    24  0.77±0.08   0.86±0.12   0.71±0.08
# 1378  bio    22  0.77±0.08   0.86±0.11   0.71±0.09
# 122    bc    21  0.77±0.08   0.84±0.12   0.72±0.08
# 1338  bio    22  0.77±0.09   0.86±0.13   0.70±0.08
# 922    bc    22  0.76±0.09   0.82±0.13   0.71±0.09
# 170   bct    21  0.75±0.09   0.81±0.13   0.72±0.09
# 1018  bio    24  0.75±0.09   0.83±0.13   0.69±0.08
# 1042   bc    22  0.74±0.09   0.82±0.13   0.69±0.08
# 263   bio    23  0.74±0.08   0.86±0.11   0.66±0.09
# 530   bct    23  0.74±0.09   0.81±0.13   0.69±0.09
# 1282   bc    23  0.74±0.09   0.83±0.13   0.67±0.08
# 834    ct    22  0.73±0.08   0.88±0.12   0.63±0.08
# 1135  bct    24  0.72±0.10   0.85±0.15   0.64±0.10
# 114    ct    24  0.72±0.08   0.86±0.13   0.62±0.08
# 674    ct    23  0.71±0.08   0.86±0.13   0.62±0.08
# 1218  bio    24  0.70±0.09   0.79±0.14   0.65±0.09
# 290   bct    19  0.70±0.09   0.79±0.14   0.64±0.09
# 594    ct    22  0.70±0.08   0.85±0.13   0.60±0.08
# 18    bio    23  0.69±0.10   0.77±0.15   0.65±0.10
# 223   bio    24  0.69±0.12   0.83±0.18   0.62±0.11
# 514    ct    23  0.68±0.08   0.85±0.12   0.58±0.08
# 1098  bio    20  0.67±0.10   0.77±0.14   0.61±0.10

# %%
Perf1['organ']=Perf1.pred.apply(lambda x:x.split(":")[1])
Perf1['study']=Perf1.pred.apply(lambda x:x.split(":")[0])


P2 = pd.pivot_table(Perf1,index=['organ','dt_in','lr','n_ds'],
               columns=['study'],
               values='f1_mn',
               aggfunc=np.mean)
P2.ix[:10]
# Out:
# study                                CHR  MGR       SUB
# organ         dt_in lr    n_ds
# Adrenal Gland bc    CART0 21    0.668436  NaN       NaN
#                           22         NaN  NaN  0.737024
#                     CART1 22    0.676669  NaN  0.736878
#                     KNN0  15    0.712927  NaN       NaN
#                           20         NaN  NaN  0.749230
#                     KNN1  15    0.702109  NaN       NaN
#                           20         NaN  NaN  0.732719
#                     NB    8     0.622161  NaN       NaN
#                           24         NaN  NaN  0.619131
#                     RF0   22    0.672647  NaN       NaN

# %% [markdown]
# # Optimal Classifiers

# %%
# What are the top classifiers by pred, dt and ?
X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},
                                             'pt':'cvt',
                                             'n_obs':{'$gte':100},
                                             'n_ds':{'$lt':25}},
                                                dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
for (pred),P_i in X.groupby(['pred']):
    for (dt), P_ij in P_i.groupby(['dt_in']):
        for (lr),P_ijk in P_ij.groupby(['lr']):
            Res = pd.concat((Res,P_ijk.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf1 = Res.reset_index(drop=True)

# %%
Perf1['res2']=Perf1.apply(lambda x: "%s:%d/%s/%s:%d" % (x.pred,x.n_obs,x.lr,x.dt_in,x.n_ds),axis=1)
Perf1['res2_f1']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.f1_mn,x.f1_sd),axis=1)
Perf1['res2_sn']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.sens_mn,x.sens_sd),axis=1)
Perf1['res2_sp']=Perf1.apply(lambda x: "%3.2f±%3.2f" % (x.spec_mn,x.spec_sd),axis=1)

# %%
P1 = None
for p in Perf1.pred.unique():
    P1 = pd.concat((P1,Perf1.query("pred=='%s'" % p).sort('f1_mn',ascending=False).head(1)))

# %%
##Table 1
P1.sort('f1_mn',ascending=False)[['res2','pred','lr','dt_in','n_obs','n_ds','res2_f1','res2_sn','res2_sp']].to_csv(DAT_DIR+'table-2.csv')

# %%
LR = pd.DataFrame(P1.lr.value_counts())
LR['pct']=100*LR.lr/P1.shape[0]
print 'LR',LR.round()
print

DT = pd.DataFrame(P1.dt_in.value_counts())
DT['pct']=100*DT.dt_in/P1.shape[0]
print 'DT',DT.round()
# Out:
# LR        lr   pct
# SVCR0  13  57.0
# KNN0    7  30.0
# RF0     3  13.0
#
# DT      dt_in   pct
# bct     12  52.0
# bio      7  30.0
# bc       3  13.0
# ct       1   4.0

# %%
Perf1['res1']=Perf1.apply(lambda x: "F1:%4.2f(%4.2f) Sn:%3.2f(%3.2f) Sp:%3.2f(%3.2f)" % \
                          (x.f1_mn,x.f1_sd,x.sens_mn,x.sens_sd,x.spec_mn,x.spec_sd),axis=1)

#Y2=pd.pivot_table(Perf1,index='pred',columns=['lr','dt_in'],values='res1',aggfunc=lambda x: np.unique(x)[0])
Perf2=pd.pivot_table(Perf1,index='pred',columns=['lr','dt_in'],values=['f1_mn','res1'],aggfunc=lambda x: np.unique(x)[0])
Perf2.head()
Y1 = Perf2['f1_mn'].max(axis=1)
Y1.sort(ascending=False)

Perf3 = Perf2['res1'][[u'NB', u'KNN0', u'KNN1',  u'RF0',u'CART0', u'CART1', u'SVCL0',u'SVCR0']].ix[Y1.index]
Perf3.to_excel(DAT_DIR+'ST5.xlsx')
Perf3.head()
# Out:
# lr                                                          NB  \
# dt_in                                                       bc
# pred
# MGR:Brain            F1:0.78(0.11) Sn:0.83(0.16) Sp:0.77(0.09)
# CHR:Urinary Bladder  F1:0.76(0.14) Sn:0.81(0.19) Sp:0.76(0.12)
# CHR:Mammary Gland    F1:0.72(0.16) Sn:0.75(0.22) Sp:0.77(0.13)
# CHR:Pancreas         F1:0.73(0.14) Sn:0.75(0.21) Sp:0.76(0.11)
# SUB:Bone Marrow      F1:0.71(0.16) Sn:0.74(0.20) Sp:0.74(0.15)
#
# lr                                                              \
# dt_in                                                      bct
# pred
# MGR:Brain            F1:0.79(0.11) Sn:0.84(0.16) Sp:0.76(0.09)
# CHR:Urinary Bladder  F1:0.77(0.12) Sn:0.83(0.16) Sp:0.76(0.10)
# CHR:Mammary Gland    F1:0.74(0.13) Sn:0.77(0.19) Sp:0.78(0.11)
# CHR:Pancreas         F1:0.74(0.12) Sn:0.79(0.18) Sp:0.74(0.09)
# SUB:Bone Marrow      F1:0.75(0.12) Sn:0.82(0.17) Sp:0.72(0.10)
#
# lr                                                              \
# dt_in                                                      bio
# pred
# MGR:Brain            F1:0.79(0.12) Sn:0.84(0.16) Sp:0.77(0.09)
# CHR:Urinary Bladder  F1:0.78(0.12) Sn:0.84(0.15) Sp:0.77(0.10)
# CHR:Mammary Gland    F1:0.70(0.16) Sn:0.74(0.23) Sp:0.72(0.14)
# CHR:Pancreas         F1:0.72(0.14) Sn:0.76(0.20) Sp:0.73(0.11)
# SUB:Bone Marrow      F1:0.76(0.12) Sn:0.82(0.17) Sp:0.73(0.10)
#
# lr                                                              \
# dt_in                                                      chm
# pred
# MGR:Brain            F1:0.72(0.19) Sn:0.78(0.25) Sp:0.74(0.15)
# CHR:Urinary Bladder  F1:0.77(0.14) Sn:0.85(0.19) Sp:0.74(0.12)
# CHR:Mammary Gland    F1:0.65(0.19) Sn:0.68(0.27) Sp:0.73(0.16)
# CHR:Pancreas         F1:0.65(0.18) Sn:0.65(0.24) Sp:0.76(0.16)
# SUB:Bone Marrow      F1:0.68(0.16) Sn:0.76(0.24) Sp:0.69(0.14)
#
# lr                                                              \
# dt_in                                                       ct
# pred
# MGR:Brain            F1:0.77(0.12) Sn:0.86(0.16) Sp:0.72(0.12)
# CHR:Urinary Bladder  F1:0.75(0.16) Sn:0.81(0.21) Sp:0.76(0.12)
# CHR:Mammary Gland    F1:0.73(0.15) Sn:0.78(0.21) Sp:0.75(0.11)
# CHR:Pancreas         F1:0.78(0.11) Sn:0.89(0.16) Sp:0.71(0.09)
# SUB:Bone Marrow      F1:0.70(0.15) Sn:0.74(0.19) Sp:0.74(0.15)
#
# lr                                                        KNN0  \
# dt_in                                                       bc
# pred
# MGR:Brain            F1:0.84(0.07) Sn:0.91(0.10) Sp:0.78(0.07)
# CHR:Urinary Bladder  F1:0.83(0.06) Sn:0.92(0.09) Sp:0.76(0.06)
# CHR:Mammary Gland    F1:0.83(0.07) Sn:0.90(0.10) Sp:0.77(0.07)
# CHR:Pancreas         F1:0.81(0.07) Sn:0.89(0.10) Sp:0.75(0.07)
# SUB:Bone Marrow      F1:0.80(0.07) Sn:0.88(0.10) Sp:0.75(0.08)
#
# lr                                                              \
# dt_in                                                      bct
# pred
# MGR:Brain            F1:0.84(0.07) Sn:0.91(0.10) Sp:0.78(0.07)
# CHR:Urinary Bladder  F1:0.83(0.07) Sn:0.91(0.09) Sp:0.77(0.07)
# CHR:Mammary Gland    F1:0.83(0.07) Sn:0.89(0.10) Sp:0.78(0.07)
# CHR:Pancreas         F1:0.81(0.07) Sn:0.89(0.10) Sp:0.75(0.07)
# SUB:Bone Marrow      F1:0.81(0.07) Sn:0.90(0.10) Sp:0.74(0.07)
#
# lr                                                              \
# dt_in                                                      bio
# pred
# MGR:Brain            F1:0.84(0.06) Sn:0.92(0.09) Sp:0.78(0.07)
# CHR:Urinary Bladder  F1:0.83(0.06) Sn:0.91(0.10) Sp:0.77(0.06)
# CHR:Mammary Gland    F1:0.82(0.07) Sn:0.91(0.10) Sp:0.76(0.07)
# CHR:Pancreas         F1:0.80(0.08) Sn:0.87(0.12) Sp:0.75(0.08)
# SUB:Bone Marrow      F1:0.80(0.07) Sn:0.88(0.10) Sp:0.74(0.07)
#
# lr                                                              \
# dt_in                                                      chm
# pred
# MGR:Brain            F1:0.83(0.07) Sn:0.92(0.11) Sp:0.76(0.07)
# CHR:Urinary Bladder  F1:0.82(0.06) Sn:0.94(0.09) Sp:0.74(0.06)
# CHR:Mammary Gland    F1:0.78(0.07) Sn:0.91(0.11) Sp:0.70(0.07)
# CHR:Pancreas         F1:0.78(0.08) Sn:0.89(0.12) Sp:0.70(0.07)
# SUB:Bone Marrow      F1:0.77(0.07) Sn:0.90(0.11) Sp:0.68(0.07)
#
# lr                                                              \
# dt_in                                                       ct
# pred
# MGR:Brain            F1:0.82(0.08) Sn:0.93(0.11) Sp:0.74(0.07)
# CHR:Urinary Bladder  F1:0.82(0.06) Sn:0.93(0.09) Sp:0.74(0.06)
# CHR:Mammary Gland    F1:0.82(0.06) Sn:0.93(0.09) Sp:0.74(0.06)
# CHR:Pancreas         F1:0.80(0.07) Sn:0.92(0.10) Sp:0.72(0.06)
# SUB:Bone Marrow      F1:0.80(0.06) Sn:0.92(0.09) Sp:0.71(0.07)
#
# lr                                     ...                      \
# dt_in                                  ...
# pred                                   ...
# MGR:Brain                              ...
# CHR:Urinary Bladder                    ...
# CHR:Mammary Gland                      ...
# CHR:Pancreas                           ...
# SUB:Bone Marrow                        ...
#
# lr                                                       SVCL0  \
# dt_in                                                       bc
# pred
# MGR:Brain            F1:0.83(0.08) Sn:0.86(0.12) Sp:0.80(0.07)
# CHR:Urinary Bladder  F1:0.82(0.08) Sn:0.86(0.12) Sp:0.79(0.08)
# CHR:Mammary Gland    F1:0.81(0.09) Sn:0.83(0.13) Sp:0.80(0.08)
# CHR:Pancreas         F1:0.79(0.09) Sn:0.81(0.14) Sp:0.79(0.08)
# SUB:Bone Marrow      F1:0.79(0.09) Sn:0.83(0.12) Sp:0.77(0.08)
#
# lr                                                              \
# dt_in                                                      bct
# pred
# MGR:Brain            F1:0.82(0.09) Sn:0.86(0.12) Sp:0.80(0.08)
# CHR:Urinary Bladder  F1:0.82(0.08) Sn:0.85(0.12) Sp:0.79(0.07)
# CHR:Mammary Gland    F1:0.81(0.08) Sn:0.83(0.13) Sp:0.80(0.08)
# CHR:Pancreas         F1:0.79(0.09) Sn:0.80(0.13) Sp:0.79(0.08)
# SUB:Bone Marrow      F1:0.80(0.08) Sn:0.84(0.12) Sp:0.77(0.08)
#
# lr                                                              \
# dt_in                                                      bio
# pred
# MGR:Brain            F1:0.83(0.08) Sn:0.86(0.12) Sp:0.81(0.07)
# CHR:Urinary Bladder  F1:0.82(0.08) Sn:0.86(0.12) Sp:0.79(0.07)
# CHR:Mammary Gland    F1:0.80(0.09) Sn:0.82(0.13) Sp:0.80(0.08)
# CHR:Pancreas         F1:0.78(0.10) Sn:0.79(0.14) Sp:0.79(0.08)
# SUB:Bone Marrow      F1:0.79(0.09) Sn:0.84(0.12) Sp:0.76(0.08)
#
# lr                                                              \
# dt_in                                                      chm
# pred
# MGR:Brain            F1:0.82(0.07) Sn:0.87(0.11) Sp:0.78(0.07)
# CHR:Urinary Bladder  F1:0.82(0.07) Sn:0.90(0.10) Sp:0.76(0.07)
# CHR:Mammary Gland    F1:0.77(0.09) Sn:0.84(0.15) Sp:0.72(0.08)
# CHR:Pancreas         F1:0.75(0.10) Sn:0.80(0.16) Sp:0.74(0.09)
# SUB:Bone Marrow      F1:0.73(0.11) Sn:0.79(0.17) Sp:0.72(0.10)
#
# lr                                                              \
# dt_in                                                       ct
# pred
# MGR:Brain            F1:0.81(0.07) Sn:0.88(0.11) Sp:0.76(0.07)
# CHR:Urinary Bladder  F1:0.81(0.07) Sn:0.88(0.11) Sp:0.76(0.07)
# CHR:Mammary Gland    F1:0.80(0.08) Sn:0.86(0.13) Sp:0.77(0.08)
# CHR:Pancreas         F1:0.79(0.08) Sn:0.87(0.13) Sp:0.74(0.08)
# SUB:Bone Marrow      F1:0.78(0.09) Sn:0.83(0.13) Sp:0.74(0.08)
#
# lr                                                       SVCR0  \
# dt_in                                                       bc
# pred
# MGR:Brain            F1:0.85(0.09) Sn:0.79(0.13) Sp:0.94(0.07)
# CHR:Urinary Bladder  F1:0.85(0.09) Sn:0.80(0.13) Sp:0.92(0.07)
# CHR:Mammary Gland    F1:0.83(0.10) Sn:0.77(0.14) Sp:0.93(0.07)
# CHR:Pancreas         F1:0.80(0.11) Sn:0.75(0.15) Sp:0.89(0.11)
# SUB:Bone Marrow      F1:0.80(0.10) Sn:0.77(0.14) Sp:0.85(0.09)
#
# lr                                                              \
# dt_in                                                      bct
# pred
# MGR:Brain            F1:0.85(0.09) Sn:0.79(0.13) Sp:0.94(0.07)
# CHR:Urinary Bladder  F1:0.85(0.09) Sn:0.80(0.13) Sp:0.93(0.07)
# CHR:Mammary Gland    F1:0.83(0.10) Sn:0.77(0.14) Sp:0.93(0.07)
# CHR:Pancreas         F1:0.80(0.11) Sn:0.75(0.16) Sp:0.89(0.10)
# SUB:Bone Marrow      F1:0.80(0.10) Sn:0.79(0.13) Sp:0.83(0.09)
#
# lr                                                              \
# dt_in                                                      bio
# pred
# MGR:Brain            F1:0.85(0.09) Sn:0.79(0.13) Sp:0.95(0.06)
# CHR:Urinary Bladder  F1:0.84(0.09) Sn:0.80(0.13) Sp:0.91(0.07)
# CHR:Mammary Gland    F1:0.83(0.11) Sn:0.76(0.15) Sp:0.94(0.07)
# CHR:Pancreas         F1:0.79(0.12) Sn:0.73(0.17) Sp:0.90(0.10)
# SUB:Bone Marrow      F1:0.80(0.10) Sn:0.75(0.14) Sp:0.87(0.09)
#
# lr                                                              \
# dt_in                                                      chm
# pred
# MGR:Brain            F1:0.83(0.09) Sn:0.84(0.13) Sp:0.83(0.08)
# CHR:Urinary Bladder  F1:0.84(0.08) Sn:0.86(0.12) Sp:0.82(0.07)
# CHR:Mammary Gland    F1:0.77(0.10) Sn:0.81(0.16) Sp:0.75(0.09)
# CHR:Pancreas         F1:0.76(0.11) Sn:0.78(0.16) Sp:0.78(0.10)
# SUB:Bone Marrow      F1:0.73(0.11) Sn:0.75(0.17) Sp:0.74(0.11)
#
# lr
# dt_in                                                       ct
# pred
# MGR:Brain            F1:0.83(0.09) Sn:0.85(0.13) Sp:0.82(0.08)
# CHR:Urinary Bladder  F1:0.82(0.08) Sn:0.85(0.12) Sp:0.81(0.07)
# CHR:Mammary Gland    F1:0.80(0.09) Sn:0.81(0.14) Sp:0.82(0.09)
# CHR:Pancreas         F1:0.78(0.10) Sn:0.82(0.15) Sp:0.77(0.09)
# SUB:Bone Marrow      F1:0.77(0.09) Sn:0.79(0.14) Sp:0.78(0.09)
#
# [5 rows x 40 columns]

# %%
study = '^SUB|^MGR'
PRED=[i for i in Outcomes_paper if re.search(study,i,re.I)]
PRED
# Out:
# [u'MGR:Brain',
#  u'MGR:Kidney',
#  u'MGR:Ovary',
#  u'MGR:Testes',
#  u'SUB:Adrenal Gland',
#  u'SUB:Bone Marrow',
#  u'SUB:Brain',
#  u'SUB:Heart',
#  u'SUB:Kidney',
#  u'SUB:Liver',
#  u'SUB:Lung',
#  u'SUB:Spleen',
#  u'SUB:Stomach',
#  u'SUB:Testes',
#  u'SUB:Thymus',
#  u'SUB:Thyroid Gland']

# %%
import matplotlib.gridspec as gridspec
import pylab as pl
import statsmodels.api as sm
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.patches import Ellipse, Circle
from matplotlib.collections import PatchCollection
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.text as text
import matplotlib.font_manager as fm 
import pylab as pl

def setAxisCol(ax,col='grey'):
    ax.tick_params(color=col, labelcolor=col)
    for spine in ax.spines.values():
        spine.set_edgecolor(col)


#LR= ['NB','KNN0','RF0','CART1','SVCR0']

X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},
                                             'pt':'cvt','n_obs':100,'n_ds':{'$lt':25}},
                                                dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
for (pred,dt,lr),P_i in X.groupby(['pred','dt_in','lr']):
    Res = pd.concat((Res,P_i.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf1 = Res.reset_index(drop=True)

for c in ['f1','sens','spec']:
    Perf1['%s_top' % c] = Perf1['%s_mn' % c]+Perf1['%s_sd' % c]
    Perf1['%s_bot' % c] = Perf1['%s_mn' % c]-Perf1['%s_sd' % c]

LR = Perf1.lr.unique()
LR = [i for i in [u'NB', u'KNN0', u'KNN1',  u'RF0',u'CART0', u'CART1', u'SVCL0',u'SVCR0'] if i in LR]
DT = ['chm','ct','bio','bc','bct']

fig = pl.figure(figsize=(15,28))

#study = '^CHR'
study = '^SUB|^MGR'
PRED=[i for i in Outcomes if re.search(study,i,re.I)]

gs1 = gridspec.GridSpec(len(PRED)+2,len(LR)+1)#,width_ratios=[1,0.5,1],height_ratios=[1,2,1])


for c_i,lr in enumerate(LR):
    
    ax = pl.subplot(gs1[0,c_i+1])
    ax.set_axis_off()
    ax.text(50,30,lr,fontdict=dict(size=20,color='#343434',horizontalalignment='center',verticalalignment='top'))
    ax.set_ylim(0,50)
    ax.set_xlim(0,100)
    #ax.set_aspect(1.5)

r_i = -1
for pred in PRED:
    
    P_best = Perf1.query("pred=='%s'" % pred).sort('f1_mn',ascending=False).reset_index(drop=True).head(1)
    if P_best.shape[0]==0: continue
    P_best=P_best.ix[0]
    best_lr = best_dt = False
    r_i += 1
    ax = pl.subplot(gs1[r_i+1,0])
    ax.set_axis_off()
    ax.text(40,25,pred,fontdict=dict(size=20,color='#343434',horizontalalignment='right',verticalalignment='center'))
    ax.set_ylim(0,50)
    ax.set_xlim(0,50)
    
    for c_i,lr in enumerate(LR):
        ax = pl.subplot(gs1[r_i+1,c_i+1])
        #ax.set_xlim(0,1)
        ax.set_ylim(0.25,1)
        ax.set_xlim(0,len(DT)+1)
        #ax.set_aspect(1.5)
        ax.grid('on',axis='x')
        setAxisCol(ax,'grey')
        #if r_i==0: ax.set_title(dt,fontdict=dict(size=20,color='#343434'))
        
        P = Perf1.query("pred=='%s' and lr=='%s'" % (pred,lr))
        best_lr = True if lr == P_best.lr else False
        ax.hlines(P_best.f1_mn,0,len(DT)+1,colors='grey',lw=1,linestyles='-',zorder=0)
        ax.hlines(P_best.f1_top,0,len(DT)+1,colors='grey',lw=0.5,linestyles='-',zorder=0)
        ax.hlines(P_best.f1_bot,0,len(DT)+1,colors='grey',lw=0.5,linestyles='-',zorder=0)
        
        for i,dt in enumerate(DT):
            
            best_dt = True if dt == P_best.dt_in and best_lr else False
                
            x = i+1
            P_i = P.query("dt_in=='%s'" % dt)
            
            if best_dt and best_lr: ax.vlines(x,0.25,1,colors='#ff6655',lw=1,zorder=0)
            
            if P_i.shape[0]==0: continue
            XY_f1= np.array([[x,P_i.f1_top],[x+0.14,float(P_i.f1_mn)],[x,P_i.f1_bot],[x-0.14,float(P_i.f1_mn)]])
            ax.add_patch(mpatches.Polygon(XY_f1,lw=0,color='#ff6600',zorder=10,alpha=1))
            
            x = i+0.75
            XY_sn= np.array([[x,P_i.sens_top],[x+0.08,float(P_i.sens_mn)],[x,P_i.sens_bot],[x-0.08,float(P_i.sens_mn)]])
            ax.add_patch(mpatches.Polygon(XY_sn,lw=0,color='#0066ff',zorder=10,alpha=1))
            
            x = i+1.25
            XY_sp= np.array([[x,P_i.spec_top],[x+0.08,float(P_i.spec_mn)],[x,P_i.spec_bot],[x-0.08,float(P_i.spec_mn)]])
            ax.add_patch(mpatches.Polygon(XY_sp,lw=0,color='#33cc33',zorder=10,alpha=1))
            
        
        ax.set_xticks(np.arange(len(DT))+1, minor=False)
        for tick in ax.get_xticklines(): tick.set_visible(False)
        
        if c_i == 0:
            ax.set_yticks([0.4,0.6,0.8], minor=False)
        else:
            for tick in ax.get_yticklabels(): tick.set_visible(False)
            for tick in ax.get_yticklines(): tick.set_visible(False)
                
        if r_i == 0:
            ax.xaxis.tick_top()
            ax.set_xticklabels(DT,rotation=90)
            for tick in ax.get_xticklabels(): tick.set_fontsize(14)
        elif r_i == len(PRED)-1:
            ax.xaxis.tick_bottom()
            ax.set_xticklabels(DT,rotation=90)
            for tick in ax.get_xticklabels(): tick.set_fontsize(14)
        else:
            for tick in ax.get_xticklabels(): tick.set_visible(False)

        
pl.subplots_adjust(wspace=0.2,hspace=0.1,top=0.9,bottom=0.1)
fig.savefig(FIG_DIR+'Figure-3-%s.png' % study.replace('|','-'),dpi=600)
fig.savefig(FIG_DIR+'Figure-3-%s.svg' % study.replace('|','-'),dpi=600)

# %% [markdown]
# ## Table 2. Optimal Classifiers / Max

# %%
# What are the top classifiers by pred, dt and ?
X = pd.DataFrame(list(DB.ml_summary_v1.find({'pred':{'$in':Outcomes},
                                             'pt':'cvt','n_obs':100,'n_ds':{'$lt':25}},
                                                dict(_id=0,pt=0,n_pos=0,n_neg=0,dt_out=0))))

Res = None
for (pred),P_i in X.groupby(['pred']):
    for (dt), P_ij in P_i.groupby(['dt_in']):
        for (lr),P_ijk in P_ij.groupby(['lr']):
            Res = pd.concat((Res,P_ijk.sort('f1_mn',ascending=False).reset_index(drop=True).head(1)))
Perf4 = Res.reset_index(drop=True)




Perf4['res2']=Perf4.apply(lambda x: "%s:%d/%s/%s:%d" % (x.pred,x.n_obs,x.lr,x.dt_in,x.n_ds),axis=1)
Perf4['res2_f1']=Perf4.apply(lambda x: "%3.2f±%3.2f" % (x.f1_mn,x.f1_sd),axis=1)
Perf4['res2_sn']=Perf4.apply(lambda x: "%3.2f±%3.2f" % (x.sens_mn,x.sens_sd),axis=1)
Perf4['res2_sp']=Perf4.apply(lambda x: "%3.2f±%3.2f" % (x.spec_mn,x.spec_sd),axis=1)

P4 = None
for p in Perf4.pred.unique():
    P4 = pd.concat((P4,Perf4.query("pred=='%s'" % p).sort('f1_mn',ascending=False).head(1)))

# %%
P4.f1_mn.mean()
# Out:
# 0.7565442811183286

# %%
Table2 = P4.sort('f1_mn',ascending=False)[['res2','pred','lr','dt_in','n_ds','res2_f1','res2_sn','res2_sp']]
Table2.columns=['Classifier id','Organ Toxicity','Algorithm','dt','n_ds','F1 Score','Sensitivity','Specificity']
#Table2.to_excel(DAT_DIR+'Table-1.xlsx',encoding='utf8')
Table2
# Out:
#                              Classifier id       Organ Toxicity Algorithm  \
# 783             MGR:Brain:100/SVCR0/bio:24            MGR:Brain     SVCR0
# 695   CHR:Urinary Bladder:100/SVCR0/bct:24  CHR:Urinary Bladder     SVCR0
# 367      CHR:Mammary Gland:100/SVCR0/bc:24    CHR:Mammary Gland     SVCR0
# 402            CHR:Pancreas:100/KNN0/bc:22         CHR:Pancreas      KNN0
# 970        SUB:Bone Marrow:100/KNN0/bct:13      SUB:Bone Marrow      KNN0
# 330         CHR:Lymph Node:100/KNN0/bct:24       CHR:Lymph Node      KNN0
# 842               MGR:Ovary:100/KNN0/bc:24            MGR:Ovary      KNN0
# 602              CHR:Thymus:100/KNN0/bc:22           CHR:Thymus      KNN0
# 50         CHR:Bone Marrow:100/KNN0/bct:24      CHR:Bone Marrow      KNN0
# 730             CHR:Uterus:100/KNN0/bct:23           CHR:Uterus      KNN0
# 1194               SUB:Lung:100/KNN0/ct:23             SUB:Lung      KNN0
# 890             MGR:Testes:100/KNN0/bct:24           MGR:Testes      KNN0
# 1274            SUB:Stomach:100/KNN0/ct:22          SUB:Stomach      KNN0
# 458    CHR:Pituitary Gland:100/KNN0/bio:24  CHR:Pituitary Gland      KNN0
# 1378     SUB:Thyroid Gland:100/KNN0/bio:22    SUB:Thyroid Gland      KNN0
# 122                 CHR:Eye:100/KNN0/bc:21              CHR:Eye      KNN0
# 1338            SUB:Thymus:100/KNN0/bio:22           SUB:Thymus      KNN0
# 922       SUB:Adrenal Gland:100/KNN0/bc:22    SUB:Adrenal Gland      KNN0
# 170              CHR:Heart:100/KNN0/bct:21            CHR:Heart      KNN0
# 1018             SUB:Brain:100/KNN0/bio:24            SUB:Brain      KNN0
# 1042              SUB:Heart:100/KNN0/bc:22            SUB:Heart      KNN0
# 263             CHR:Liver:100/SVCR0/bio:23            CHR:Liver     SVCR0
# 530            CHR:Stomach:100/KNN0/bct:23          CHR:Stomach      KNN0
# 1282             SUB:Testes:100/KNN0/bc:23           SUB:Testes      KNN0
# 834              MGR:Kidney:100/KNN0/ct:22           MGR:Kidney      KNN0
# 1135            SUB:Liver:100/SVCR0/bct:24            SUB:Liver     SVCR0
# 114               CHR:Brain:100/KNN0/ct:24            CHR:Brain      KNN0
# 674       CHR:Thyroid Gland:100/KNN0/ct:23    CHR:Thyroid Gland      KNN0
# 1218            SUB:Spleen:100/KNN0/bio:24           SUB:Spleen      KNN0
# 290               CHR:Lung:100/KNN0/bct:19             CHR:Lung      KNN0
# 594              CHR:Testes:100/KNN0/ct:22           CHR:Testes      KNN0
# 18       CHR:Adrenal Gland:100/KNN0/bio:23    CHR:Adrenal Gland      KNN0
# 223            CHR:Kidney:100/SVCR0/bio:24           CHR:Kidney     SVCR0
# 514              CHR:Spleen:100/KNN0/ct:23           CHR:Spleen      KNN0
# 1098            SUB:Kidney:100/KNN0/bio:20           SUB:Kidney      KNN0
#
#        dt  n_ds   F1 Score Sensitivity Specificity
# 783   bio    24  0.85±0.09   0.79±0.13   0.95±0.06
# 695   bct    24  0.85±0.09   0.80±0.13   0.93±0.07
# 367    bc    24  0.83±0.10   0.77±0.14   0.93±0.07
# 402    bc    22  0.81±0.07   0.89±0.10   0.75±0.07
# 970   bct    13  0.81±0.07   0.90±0.10   0.74±0.07
# 330   bct    24  0.81±0.07   0.89±0.10   0.74±0.07
# 842    bc    24  0.81±0.08   0.87±0.11   0.75±0.07
# 602    bc    22  0.80±0.08   0.87±0.11   0.75±0.08
# 50    bct    24  0.79±0.07   0.89±0.10   0.72±0.07
# 730   bct    23  0.79±0.08   0.86±0.12   0.73±0.08
# 1194   ct    23  0.78±0.07   0.91±0.10   0.69±0.07
# 890   bct    24  0.78±0.08   0.86±0.12   0.72±0.08
# 1274   ct    22  0.78±0.07   0.90±0.11   0.69±0.07
# 458   bio    24  0.77±0.08   0.86±0.12   0.71±0.08
# 1378  bio    22  0.77±0.08   0.86±0.11   0.71±0.09
# 122    bc    21  0.77±0.08   0.84±0.12   0.72±0.08
# 1338  bio    22  0.77±0.09   0.86±0.13   0.70±0.08
# 922    bc    22  0.76±0.09   0.82±0.13   0.71±0.09
# 170   bct    21  0.75±0.09   0.81±0.13   0.72±0.09
# 1018  bio    24  0.75±0.09   0.83±0.13   0.69±0.08
# 1042   bc    22  0.74±0.09   0.82±0.13   0.69±0.08
# 263   bio    23  0.74±0.08   0.86±0.11   0.66±0.09
# 530   bct    23  0.74±0.09   0.81±0.13   0.69±0.09
# 1282   bc    23  0.74±0.09   0.83±0.13   0.67±0.08
# 834    ct    22  0.73±0.08   0.88±0.12   0.63±0.08
# 1135  bct    24  0.72±0.10   0.85±0.15   0.64±0.10
# 114    ct    24  0.72±0.08   0.86±0.13   0.62±0.08
# 674    ct    23  0.71±0.08   0.86±0.13   0.62±0.08
# 1218  bio    24  0.70±0.09   0.79±0.14   0.65±0.09
# 290   bct    19  0.70±0.09   0.79±0.14   0.64±0.09
# 594    ct    22  0.70±0.08   0.85±0.13   0.60±0.08
# 18    bio    23  0.69±0.10   0.77±0.15   0.65±0.10
# 223   bio    24  0.69±0.12   0.83±0.18   0.62±0.11
# 514    ct    23  0.68±0.08   0.85±0.12   0.58±0.08
# 1098  bio    20  0.67±0.10   0.77±0.14   0.61±0.10

# %% [markdown]
# # Bioactivity Signature

# %%
DB.ml_lr_v1.find({'pred':'CHR:Liver','dt_in':'bio','perf_cvt.f1_mn':{'$gte':0.8},'n_ds':{'$lt':20}}).count()
#DB.ml_lr_v1.find_one({'pred':'CHR:Liver','dt_in':'bio','perf_cvt.f1_mn':{'$gt':0.7},'n_ds':{'$lt':25}},dict(_id=0))
# Out:
# 391

# %%
from viz.net import *
import networkx as nx
from itertools import combinations

def updateLr2Net(Markers,Output,G=None):
    #if not (G and Markers and Output): return

    def addEdge(i,j):
        if G.has_edge(i,j):
            G[i][j]['n']+=1
        else:
            G.add_edge(i,j,dict(n=1))
        
    for (v1,v2) in combinations(Markers,2): addEdge(v1,v2)
    for (v1,v2) in [(i,Output) for i in Markers]: addEdge(v1,v2)
        
    
NV0 = NetViz(directed=False)
G0  = nx.Graph()

Q0  = {'pred':None,'dt_in':'bio','perf_cvt.f1_mn':{'$gt':0.8},'n_ds':{'$lt':20}}
Q1  = {'pred':None,'dt_in':'bio','n_ds':{'$lt':20}}

for tox in Outcomes:
    Q1['pred']=tox
    # Find the 95% F1_mn score for tox
    F1 = [Lr['perf_cvt']['f1_mn'] for Lr in DB.ml_lr_v1.find(Q1)]
    p1 = np.percentile(F1,q=95)
    print '>',tox,p1
    Q0['pred']=tox
    Q0['perf_cvt.f1_mn']={'$gte':p1}
    for Lr in DB.ml_lr_v1.find(Q0):
        updateLr2Net(Lr['perf_trn']['ds'],Lr['pred'],G=G0)
# Out:
# > CHR:Adrenal Gland 0.790900616574
# > CHR:Bone Marrow 0.853330960747
# > CHR:Brain 0.811627374877
# > CHR:Eye 0.827822735625
# > CHR:Heart 0.841999637237
# > CHR:Kidney 0.760672606259
# > CHR:Liver 0.755871528777
# > CHR:Lung 0.792530007897
# > CHR:Lymph Node 0.85316509412
# > CHR:Mammary Gland 0.863571706369
# > CHR:Pancreas 0.856377176902
# > CHR:Pituitary Gland 0.832640238415
# > CHR:Spleen 0.789959489233
# > CHR:Stomach 0.811492618421
# > CHR:Testes 0.796523871496
# > CHR:Thymus 0.832487408377
# > CHR:Thyroid Gland 0.804703646615
# > CHR:Urinary Bladder 0.858520445036
# > CHR:Uterus 0.837576221917
# > MGR:Brain 0.876989735035
# > MGR:Kidney 0.821897386532
# > MGR:Ovary 0.848830572673
# > MGR:Testes 0.8481171462
# > SUB:Adrenal Gland 0.821746735238
# > SUB:Bone Marrow 0.875426390044
# > SUB:Brain 0.834873235511
# > SUB:Heart 0.816224197162
# > SUB:Kidney 0.732789029958
# > SUB:Liver 0.720776962897
# > SUB:Lung 0.845813974681
# > SUB:Spleen 0.801573650111
# > SUB:Stomach 0.840956702641
# > SUB:Testes 0.832710909238
# > SUB:Thymus 0.839058182916
# > SUB:Thyroid Gland 0.842799607475

# %%
tox = 'CHR:Brain'
X = [v['n'] for v in G0[tox].values()]
print [(i,np.percentile(X,q=i)) for i in np.linspace(0,100,num=5)]
n0 = np.percentile(X,q=90)
pl.hist(X,20,rwidth=0.8,color='orange')
E0= sorted([(k,v['n']) for k,v in G0[tox].iteritems() if v['n']>=n0],key=lambda x:x[1],reverse=True)
E0
# Out:
# [(0.0, 1.0), (25.0, 14.0), (50.0, 42.0), (75.0, 90.0), (100.0, 768.0)]
# [(u'BSK_LPS_PGE2_down', 768),
#  (u'ATG_C_EBP_CIS_up', 694),
#  (u'ATG_CRE_CIS_up', 559),
#  (u'APR_HepG2_StressKinase_1h_up', 532),
#  (u'Tox21_AutoFluor_HEK293_Media_red', 522),
#  (u'ATG_PPARa_TRANS_up', 516),
#  (u'ATG_BRE_CIS_up', 500),
#  (u'OT_ER_ERaERa_0480', 485),
#  (u'ATG_MRE_CIS_up', 435),
#  (u'NVS_NR_hPPARg', 399),
#  (u'Tox21_PPARd_BLA_agonist_ratio', 345),
#  (u'APR_HepG2_MicrotubuleCSK_72h_up', 341),
#  (u'NVS_TR_hNET', 331),
#  (u'APR_HepG2_MitoticArrest_1h_dn', 318),
#  (u'ATG_SREBP_CIS_up', 286),
#  (u'NVS_GPCR_p5HT2C', 274),
#  (u'NVS_NR_hGR', 267),
#  (u'BSK_CASM3C_TissueFactor_down', 265),
#  (u'Tox21_AR_LUC_MDAKB2_Antagonist', 249),
#  (u'OT_AR_ARSRC1_0480', 245),
#  (u'BSK_CASM3C_IL8_down', 241),
#  (u'Tox21_VDR_BLA_antagonist_viability', 236),
#  (u'ATG_E_Box_CIS_up', 232),
#  (u'Tox21_AR_BLA_Agonist_ratio', 228),
#  (u'Tox21_MitochondrialToxicity_viability', 217)]

# %%
G0[tox].items()[:10]
# Out:
# [(u'NVS_ENZ_hPDE5', {'n': 48}),
#  (u'ATG_M_61_CIS_up', {'n': 10}),
#  (u'NVS_NR_hCAR_Antagonist', {'n': 47}),
#  (u'ATG_NRF1_CIS_up', {'n': 41}),
#  (u'APR_HepG2_MitoticArrest_1h_dn', {'n': 63}),
#  (u'APR_HepG2_MitoticArrest_24h_dn', {'n': 6}),
#  (u'ATG_EGR_CIS_up', {'n': 104}),
#  (u'BSK_LPS_TissueFactor_down', {'n': 4}),
#  (u'BSK_LPS_TNFa_down', {'n': 64}),
#  (u'ATG_TGFb_CIS_up', {'n': 26})]

# %%
G1 = nx.Graph()

E0 = []

for tox in Outcomes:
    X = [v['n'] for v in G0[tox].values()]
    n0 = np.percentile(X,q=99)
    E0 += [(tox,k,v) for k,v in G0[tox].iteritems() if v['n']>=n0]
    
E1 = []

X = []
for (v1,v2,d) in G0.edges(data=True):
    if d['n']<1000: continue
    E1 += [(v1,v2,d)]
    #if v1 in Outcomes or v2 in Outcomes: continue
    #X.append(d['n'])

len(E0),len(E1)

# %%
pl.hist(X,20,rwidth=0.8,color='orange',log=True)
np.percentile(X,q=90)
# Out:
# 128.0

# %%
G1.add_edges_from(E1)
G1.add_edges_from(E0)

NV0.G = G1
P=NV0.layout()

# %%
fig = pl.figure(figsize=(20,20))
ax = pl.subplot(1,1,1)
NV0.G = G1
P=NV0.layout()

NV0.draw(alg='neato')

# %%
Res = []
for tox in Outcomes:
    X = [v['n'] for v in G0[tox].values()]
    #print [(i,np.percentile(X,q=i)) for i in np.linspace(0,100,num=5)]
    n0 = np.percentile(X,q=95)
    E0= sorted([(tox,k,v['n']) for k,v in G0[tox].iteritems() if v['n']>=n0],key=lambda x:x[1],reverse=True)
    Res += E0
R0 = pd.DataFrame(Res,columns=['tox','bio','n'])

# %%
B0 = R0.pivot_table(index='tox',columns='bio',values='n',fill_value=0)

# %% [markdown]
# # What are the top classifiers by pred, dt and ?

# %% [markdown]
# ## Find the most frequent descriptors by bio for SUB
#
# For each tox outcome find the > 80% of best classifiers and count the frequency of bio descriptors by each tox

# %%
Res={}

def addRes(Z,D):
    for x in Z:
        if D.has_key(x): D[x]+=1
        else: D[x]=1

#Q0  = {'pred':None,'dt_in':'bio','perf_cvt.f1_mn':{'$gt':0.8},'n_ds':{'$lt':20}}
#Q1  = {'pred':None,'dt_in':'bio','n_ds':{'$lt':20}}
Q1  = {'pred':None,'dt_in':'bio'}

for tox in Outcomes:
    Q1['pred']=tox
    # Find the 95% F1_mn score for tox
    F1 = [Lr['perf_cvt']['f1_mn'] for Lr in DB.ml_lr_v1.find(Q1)]
    p1 = np.percentile(F1,q=75)
    print '>',tox,p1
    Q0['pred']=tox
    Q0['perf_cvt.f1_mn']={'$gte':p1}
    Res[tox]={}
    for X in DB.ml_lr_v1.find(Q0,
                             {'_id':0,
                               'pred':1,'dt_in':1,
                               'perf_trn.ds':1}):
        
            addRes(X['perf_trn']['ds'],Res[tox])
# Out:
# > CHR:Adrenal Gland 0.752363947742
# > CHR:Bone Marrow 0.823038446462
# > CHR:Brain 0.775906239549
# > CHR:Eye 0.798656130758
# > CHR:Heart 0.806680069481
# > CHR:Kidney 0.711112622846
# > CHR:Liver 0.697212655897
# > CHR:Lung 0.756852769393
# > CHR:Lymph Node 0.820486476431
# > CHR:Mammary Gland 0.842772515018
# > CHR:Pancreas 0.829861510633
# > CHR:Pituitary Gland 0.798754402317
# > CHR:Spleen 0.754629059421
# > CHR:Stomach 0.779089016828
# > CHR:Testes 0.761019141086
# > CHR:Thymus 0.803778689206
# > CHR:Thyroid Gland 0.766700694103
# > CHR:Urinary Bladder 0.836331159132
# > CHR:Uterus 0.81098439288
# > MGR:Brain 0.845899784666
# > MGR:Kidney 0.787280409842
# > MGR:Ovary 0.81620354685
# > MGR:Testes 0.815547875664
# > SUB:Adrenal Gland 0.787446543501
# > SUB:Bone Marrow 0.848120394453
# > SUB:Brain 0.803691947977
# > SUB:Heart 0.784422308937
# > SUB:Kidney 0.685041178383
# > SUB:Liver 0.664955476946
# > SUB:Lung 0.820402026356
# > SUB:Spleen 0.767569997336
# > SUB:Stomach 0.803905187046
# > SUB:Testes 0.801024325254
# > SUB:Thymus 0.809662178781
# > SUB:Thyroid Gland 0.814411746498

# %%
TopBio0 = pd.DataFrame(Res).T
TopBio0.shape
Exc0 = [i for i in TopBio0.columns if re.search('autofluo',i,re.I)]
TopBio0.drop(Exc0,axis=1,inplace=True)
TopBio0.fillna(0,inplace=True)

import pylab as pl
N0 = TopBio0.max(axis=0)
B0 = N0[N0>2275].index
TopBio1 = TopBio0[B0]

len(B0)
# Out:
# 567

# %%
TopBio0 = pd.DataFrame(Res1).T
TopBio0.shape
Exc0 = [i for i in TopBio0.columns if re.search('autofluo',i,re.I)]
I1 = [i for i in TopBio0.index if i.startswith('SUB')]
TopBio0.drop(Exc0,axis=1,inplace=True)
TopBio0.fillna(0,inplace=True)
TopBio0 = TopBio0.ix[I1]
N1 = TopBio0.mean(axis=0)
#B1 = N1[N1>300].index


B1 = N1.sort_values(ascending=False).index[:50]
len(B1)
TopBio2 = TopBio0[B1]
TopBio2.ix[:,:10]
# Out:
#                    Tox21_PPARd_BLA_agonist_ratio  NVS_NR_hER  \
# SUB:Adrenal Gland                         8327.0      1774.0
# SUB:Bone Marrow                            432.0      1416.0
# SUB:Brain                                15554.0      6419.0
# SUB:Heart                                 7597.0     19988.0
# SUB:Kidney                                4969.0      2931.0
# SUB:Liver                                 4939.0      5297.0
# SUB:Lung                                   397.0       446.0
# SUB:Spleen                               12252.0     25230.0
# SUB:Stomach                                738.0       718.0
# SUB:Testes                               27581.0      4937.0
# SUB:Thymus                                 846.0      2923.0
# SUB:Thyroid Gland                         1246.0      2510.0
#
#                    ATG_DR4_LXR_CIS_up  ATG_LXRb_TRANS_up  OT_ER_ERaERa_1440  \
# SUB:Adrenal Gland              9595.0             8884.0              834.0
# SUB:Bone Marrow                 192.0              376.0             1632.0
# SUB:Brain                     13795.0             2904.0             2026.0
# SUB:Heart                      6059.0             3741.0              690.0
# SUB:Kidney                      928.0             4759.0             3410.0
# SUB:Liver                       193.0             7387.0             3725.0
# SUB:Lung                        436.0             1896.0              748.0
# SUB:Spleen                      954.0            15367.0            20328.0
# SUB:Stomach                     239.0              280.0              602.0
# SUB:Testes                    30078.0              961.0             2111.0
# SUB:Thymus                      517.0             3159.0            12886.0
# SUB:Thyroid Gland               106.0             1283.0              766.0
#
#                    APR_HepG2_MitoMembPot_24h_dn  OT_ER_ERaERa_0480  \
# SUB:Adrenal Gland                        2279.0             2791.0
# SUB:Bone Marrow                          1656.0             3047.0
# SUB:Brain                                2375.0             3774.0
# SUB:Heart                                1855.0             1519.0
# SUB:Kidney                               1729.0             5691.0
# SUB:Liver                                 514.0             3518.0
# SUB:Lung                                  571.0             1392.0
# SUB:Spleen                              21245.0            11691.0
# SUB:Stomach                               210.0             1048.0
# SUB:Testes                               1088.0              972.0
# SUB:Thymus                                606.0            10395.0
# SUB:Thyroid Gland                       14098.0             1093.0
#
#                    APR_HepG2_MitoMass_1h_up  APR_HepG2_MitoMembPot_1h_dn  \
# SUB:Adrenal Gland                    2450.0                      17670.0
# SUB:Bone Marrow                      1120.0                       4744.0
# SUB:Brain                             464.0                        614.0
# SUB:Heart                           19742.0                       5598.0
# SUB:Kidney                           5775.0                       1371.0
# SUB:Liver                            4802.0                       1785.0
# SUB:Lung                              367.0                        818.0
# SUB:Spleen                           8000.0                       6075.0
# SUB:Stomach                           152.0                        104.0
# SUB:Testes                            928.0                        946.0
# SUB:Thymus                           2730.0                       1012.0
# SUB:Thyroid Gland                       0.0                       5354.0
#
#                    APR_HepG2_StressKinase_1h_up
# SUB:Adrenal Gland                       10473.0
# SUB:Bone Marrow                          2808.0
# SUB:Brain                                2407.0
# SUB:Heart                                4145.0
# SUB:Kidney                               9526.0
# SUB:Liver                                4308.0
# SUB:Lung                                 3215.0
# SUB:Spleen                               2725.0
# SUB:Stomach                               312.0
# SUB:Testes                               1080.0
# SUB:Thymus                               2957.0
# SUB:Thyroid Gland                        1725.0

# %%
X2 = X1.apply(lambda x: (x-x.min())/(x.max()-x.min()),axis=1)
#J0 = X2.mean(axis=0)
#J0.sort(ascending=False)
#J0[:50]
X3 = X2.ix['SUB:Liver']
X3.sort(ascending=False)
X3
# Out:
# NVS_ENZ_hBACE                        1.000000
# ATG_LXRb_TRANS_up                    0.706566
# BSK_CASM3C_IL8_up                    0.651947
# NVS_TR_hDAT                          0.568274
# NVS_NR_hER                           0.504164
# NVS_ADME_hCYP2C18                    0.484021
# Tox21_PPARd_BLA_agonist_ratio        0.469494
# APR_HepG2_MitoMass_1h_up             0.456227
# APR_HepG2_StressKinase_1h_up         0.408387
# NVS_ADME_hCYP2C19                    0.398218
# ATG_PXRE_CIS_up                      0.386016
# OT_ER_ERaERa_1440                    0.351927
# OT_ER_ERaERa_0480                    0.331881
# NVS_NR_hPXR                          0.302440
# APR_HepG2_MitoMass_24h_up            0.299826
# ATG_CMV_CIS_up                       0.278133
# APR_HepG2_MicrotubuleCSK_72h_up      0.275905
# OT_ER_ERaERb_0480                    0.225353
# ATG_ERE_CIS_up                       0.219252
# APR_HepG2_MitoMembPot_1h_dn          0.164052
# Tox21_ERa_LUC_BG1_Agonist            0.163568
# ATG_DR5_CIS_up                       0.153980
# ACEA_T47D_80hr_Negative              0.153012
# NVS_ADME_rCYP3A1                     0.147395
# ATG_PPRE_CIS_up                      0.143618
# BSK_hDFCGF_PAI1_down                 0.129576
# ATG_PPARg_TRANS_up                   0.117567
# OT_ER_ERbERb_0480                    0.110885
# APR_HepG2_MitoMass_72h_up            0.106043
# NVS_ADME_hCYP19A1                    0.105752
# ATG_ERa_TRANS_up                     0.105559
# APR_HepG2_CellCycleArrest_1h_up      0.097037
# Tox21_AR_BLA_Agonist_ratio           0.092485
# ATG_CAR_TRANS_up                     0.086771
# OT_ER_ERaERb_1440                    0.080089
# ATG_SREBP_CIS_up                     0.075828
# ATG_NURR1_TRANS_up                   0.066822
# ATG_PXR_TRANS_up                     0.066434
# APR_HepG2_NuclearSize_1h_up          0.053554
# ATG_EGR_CIS_up                       0.050939
# ATG_MRE_CIS_up                       0.047259
# ATG_NF_kB_CIS_up                     0.042417
# APR_HepG2_MitoMembPot_24h_dn         0.040965
# APR_HepG2_CellCycleArrest_24h_up     0.025567
# Tox21_MitochondrialToxicity_ratio    0.022564
# NVS_NR_hPPARg                        0.022177
# BSK_CASM3C_MIG_down                  0.014526
# ATG_DR4_LXR_CIS_up                   0.009878
# Tox21_ARE_BLA_agonist_viability      0.003390
# NVS_GPCR_gOpiateK                    0.000000
# Name: SUB:Liver, dtype: float64

# %%
Res=[]
BIO=list(TopBio0.columns)
for tox in TopBio0.index:
    CID = DB.tox_fp.find({'tox_fpp1.ds':tox}).distinct('dsstox_cid')
    print '>',tox,len(CID)
    for bio in BIO:
        Res.append(dict(tox=tox,bio=bio,n=DB.bio_fp.find({'dsstox_cid':{'$in':CID},'bio1.ds':bio}).count()))
# Out:
# > CHR:Adrenal Gland 188
# > CHR:Bone Marrow 78
# > CHR:Brain 136
# > CHR:Eye 93
# > CHR:Heart 128
# > CHR:Kidney 324
# > CHR:Liver 414
# > CHR:Lung 183
# > CHR:Lymph Node 73
# > CHR:Mammary Gland 64
# > CHR:Pancreas 66
# > CHR:Pituitary Gland 76
# > CHR:Spleen 205
# > CHR:Stomach 134
# > CHR:Testes 164
# > CHR:Thymus 72
# > CHR:Thyroid Gland 169
# > CHR:Urinary Bladder 53
# > CHR:Uterus 86
# > MGR:Brain 51
# > MGR:Kidney 147
# > MGR:Ovary 65
# > MGR:Testes 91
# > SUB:Adrenal Gland 126
# > SUB:Bone Marrow 82
# > SUB:Brain 117
# > SUB:Heart 134
# > SUB:Kidney 313
# > SUB:Liver 387
# > SUB:Lung 87
# > SUB:Spleen 176
# > SUB:Stomach 88
# > SUB:Testes 159
# > SUB:Thymus 100
# > SUB:Thyroid Gland 88

# %%
TopBio0 = pd.DataFrame(Res).pivot_table(index='tox',columns='bio',values='n',fill_value=0)
TopBio0.ix[:10,:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-635-8f21f1559e2d> in <module>()
# ----> 1 TopBio0 = pd.DataFrame(Res).pivot_table(index='tox',columns='bio',values='n',fill_value=0)
#       2 TopBio0.ix[:10,:10]
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/tools/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     118             data = data[to_filter]
#     119
# --> 120     grouped = data.groupby(keys)
#     121     agged = grouped.agg(aggfunc)
#     122
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     352                                                     level=level,
#     353                                                     sort=sort,
# --> 354                                                     mutated=self.mutated)
#     355
#     356         self.obj = obj
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2381
#    2382         elif is_in_axis(gpr):  # df.groupby('name')
# -> 2383             in_axis, name, gpr = True, gpr, obj[gpr]
#    2384             exclusions.append(name)
#    2385
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/anaconda2/lib/python2.7/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'tox'

# %%
I1 = [i for i in TopBio0.index if i.startswith('SUB')]
X1 = TopBio0.ix[I1]
TopBio1 = X1.apply(lambda x: (x-x.min())/(x.max()-x.min()),axis=1)
J0 = TopBio1.max(axis=0)
J0.sort(ascending=False)
J1 = J0.index[:50]
TopBio2 = TopBio0.ix[I1,J1]
TopBio2.shape
# Out:
# (12, 50)

# %%
[i for i in TopBio0.columns if i.find('EBP')>-1]
J0[[u'ATG_C_EBP_CIS_up','APR_HepG2_MicrotubuleCSK_72h_up']]
# Out:
# bio
# ATG_C_EBP_CIS_up                   0.845070
# APR_HepG2_MicrotubuleCSK_72h_up    0.711864
# dtype: float64

# %%
for i in ['C_EBP','PPARg','Stress','Microtubule','PBREM','CellCycle','CellLoss']:
    C = [j for j in TopBio2.columns if j.find(i)>-1]
    print i,'\t',','.join(C)
# Out:
# C_EBP 	ATG_C_EBP_CIS_up
# PPARg 	ATG_PPARg_TRANS_up
# Stress 	APR_HepG2_OxidativeStress_72h_up
# Microtubule 	APR_HepG2_MicrotubuleCSK_72h_up
# PBREM 	ATG_PBREM_CIS_up
# CellCycle
# CellLoss 	APR_HepG2_CellLoss_72h_dn,APR_HepG2_CellLoss_24h_dn

# %%
# 
# Visualize the associations between Liver Tox categories and informative descriptors
#

import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
import matplotlib.path as mpath
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import matplotlib.text as text
import matplotlib.font_manager as fm 
import pylab as pl
from matplotlib.patches import Ellipse, Circle, Rectangle
from collections import *
import matplotlib.cm as cm
import matplotlib as mpl
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.spatial.distance import pdist


import matplotlib.gridspec as gridspec
from sklearn import preprocessing


DF2 = pd.DataFrame(preprocessing.scale(TopBio2,axis=1,with_std=True),index=TopBio2.index,columns=TopBio2.columns)
#DF2 = pd.DataFrame(preprocessing.scale(DF2,axis=0,with_std=True),index=DF2.index,columns=DF2.columns)
#DF2 = DF2.ix[[i for i in DF2.index if i.startswith("SUB")],:]
#DF2 = TopBio2


fig = pl.figure(figsize=(23,6),dpi=600)
#fig = pl.figure(figsize=(16,6),dpi=600)

gs1 = gridspec.GridSpec(3,3,width_ratios=[0.1,2,0.1],height_ratios=[0.15,1,0.2])

# Cluster and visualize dendrogram for descriptors
ax = pl.subplot(gs1[0,1])
dnd_col=dendrogram(linkage(pdist(DF2.T,metric='cosine'),method='weighted'),orientation='top')#,count_sort=True)
ax.set_axis_off()

# Cluster and visualize dendrogram for toxicities
ax = pl.subplot(gs1[1,2])
dnd_row=dendrogram(linkage(pdist(DF2,metric='cosine'),method='average'),orientation='right')#,count_sort=True)
ax.set_axis_off()

# Visualize the distribution of values for descriptors
dsc1=DF2.columns[dnd_col['leaves']]
ax = pl.subplot(gs1[1,1])
X1=DF2.ix[dnd_row['leaves'],dnd_col['leaves']]
hm1=ax.pcolor(X1,cmap=cm.RdYlBu_r,edgecolor='white',lw=3,vmin=-1,vmax=1)
#hm1=ax.pcolor(X1,cmap=cm.jet,edgecolor='white',lw=3)
ax.xaxis.tick_bottom()

ax.set_xticks(np.arange(len(dsc1))+0.5, minor=False)
xl=ax.set_xticklabels([i.replace('_',' ') for i in dsc1], minor=False,rotation=90)
for tick in ax.get_xticklines(): 
    tick.set_visible(False)
for tick in ax.get_xticklabels(): 
    tick.set_fontsize(10)


tox1 = DF2.index[dnd_row['leaves']]
ax.set_yticks(np.arange(len(tox1))+0.5, minor=False)
yl=ax.set_yticklabels(tox1, minor=False)

for tick in ax.get_yticklabels(): 
    tick.set_fontsize(14)
for tick in ax.get_yticklines(): 
    tick.set_visible(False)

ax.set_xlim(0,len(dsc1))
ax.set_ylim(0,len(tox1))

#ax = pl.subplot(gs1[2,2])
#pl.colorbar(hm1,ax=ax,shrink=3.0)
#ax.set_axis_off()

ax1 = fig.add_axes([-0.09,0.0,0.15,0.08])
pl.colorbar(hm1,ax=ax1,shrink=5)
ax1.set_axis_off()

pl.subplots_adjust(wspace=0,hspace=0,top=1,bottom=0)
pl.savefig(FIG_DIR+'Figure-4.2.png',bbox_inches='tight')
pl.savefig(FIG_DIR+'Figure-4.2.svg',bbox_inches='tight')

# %%
X1 = TopBio2.apply(lambda x: (x-x.min())/(x.max()-x.min()),axis=1)
E1 = []
for tox in X1.index:
    if not tox.startswith('SUB'): continue
    x = X1.ix[tox]
    x.sort(ascending=False)
    E1+= [(tox,i,dict(f=v)) for (i,v) in x[:3].to_dict().items()]

# %%
E1
# Out:
# [(u'CHR:Adrenal Gland', u'ATG_CRE_CIS_up', 0.93512110726643594),
#  (u'CHR:Adrenal Gland', u'Tox21_TR_LUC_GH3_Agonist', 0.64965397923875434),
#  (u'CHR:Adrenal Gland', u'ATG_C_EBP_CIS_up', 1.0),
#  (u'CHR:Adrenal Gland', u'BSK_BE3C_SRB_down', 0.55103806228373697),
#  (u'CHR:Adrenal Gland', u'ATG_Oct_MLP_CIS_up', 0.94117647058823528),
#  (u'CHR:Bone Marrow',
#   u'Tox21_PPARg_BLA_antagonist_ratio',
#   0.36896046852122988),
#  (u'CHR:Bone Marrow', u'ATG_CAR_TRANS_up', 1.0),
#  (u'CHR:Bone Marrow', u'ATG_NF_kB_CIS_up', 0.24158125915080528),
#  (u'CHR:Bone Marrow', u'ATG_C_EBP_CIS_up', 0.30600292825768666),
#  (u'CHR:Bone Marrow', u'Tox21_TR_LUC_GH3_Agonist', 0.28404099560761348),
#  (u'CHR:Brain', u'ATG_CRE_CIS_up', 0.8054755043227666),
#  (u'CHR:Brain', u'APR_HepG2_StressKinase_1h_up', 0.7665706051873199),
#  (u'CHR:Brain', u'ATG_MRE_CIS_up', 0.62680115273775217),
#  (u'CHR:Brain', u'ATG_C_EBP_CIS_up', 1.0),
#  (u'CHR:Brain', u'ATG_BRE_CIS_up', 0.72046109510086453),
#  (u'CHR:Eye', u'APR_HepG2_MitoMass_72h_up', 0.6071428571428571),
#  (u'CHR:Eye', u'ATG_BRE_CIS_up', 0.86190476190476195),
#  (u'CHR:Eye', u'ATG_NF_kB_CIS_up', 1.0),
#  (u'CHR:Eye', u'BSK_BE3C_SRB_down', 0.90238095238095239),
#  (u'CHR:Eye', u'APR_HepG2_CellLoss_24h_dn', 0.53333333333333333),
#  (u'CHR:Heart', u'ATG_CRE_CIS_up', 0.83770287141073663),
#  (u'CHR:Heart', u'ATG_BRE_CIS_up', 0.57240948813982517),
#  (u'CHR:Heart', u'ATG_C_EBP_CIS_up', 1.0),
#  (u'CHR:Heart', u'APR_HepG2_MicrotubuleCSK_72h_up', 0.47690387016229713),
#  (u'CHR:Heart', u'ATG_Oct_MLP_CIS_up', 0.43445692883895132),
#  (u'CHR:Kidney', u'ATG_BRE_CIS_up', 1.0),
#  (u'CHR:Kidney', u'ATG_PXRE_CIS_up', 0.99034830046160305),
#  (u'CHR:Kidney', u'ATG_C_EBP_CIS_up', 0.88292068820814096),
#  (u'CHR:Kidney', u'ATG_PPARg_TRANS_up', 0.75409148132605963),
#  (u'CHR:Kidney', u'ATG_PPRE_CIS_up', 0.60805707091900962),
#  (u'CHR:Liver', u'ATG_C_EBP_CIS_up', 0.6586826347305389),
#  (u'CHR:Liver', u'APR_HepG2_StressKinase_1h_up', 1.0),
#  (u'CHR:Liver', u'ATG_PXRE_CIS_up', 0.81936127744510978),
#  (u'CHR:Liver', u'APR_HepG2_MitoMembPot_24h_dn', 0.93313373253493015),
#  (u'CHR:Liver', u'BSK_BE3C_SRB_down', 0.76447105788423153),
#  (u'CHR:Lung', u'OT_PPARg_PPARgSRC1_1440', 0.79876160990712075),
#  (u'CHR:Lung', u'Tox21_TR_LUC_GH3_Antagonist', 0.92569659442724461),
#  (u'CHR:Lung', u'ACEA_T47D_80hr_Positive', 1.0),
#  (u'CHR:Lung', u'OT_ER_ERbERb_1440', 0.82352941176470584),
#  (u'CHR:Lung', u'Tox21_AhR', 0.84520123839009287),
#  (u'CHR:Lymph Node', u'APR_HepG2_CellLoss_24h_dn', 0.51715686274509809),
#  (u'CHR:Lymph Node', u'APR_HepG2_MitoticArrest_72h_up', 0.48039215686274511),
#  (u'CHR:Lymph Node', u'APR_HepG2_CellCycleArrest_72h_dn', 0.76470588235294112),
#  (u'CHR:Lymph Node', u'APR_HepG2_CellLoss_72h_dn', 0.38235294117647056),
#  (u'CHR:Lymph Node', u'BSK_3C_HLADR_down', 1.0),
#  (u'CHR:Mammary Gland',
#   u'APR_HepG2_MicrotubuleCSK_72h_up',
#   0.59999999999999998),
#  (u'CHR:Mammary Gland', u'OT_FXR_FXRSRC1_0480', 0.60666666666666669),
#  (u'CHR:Mammary Gland', u'ATG_NF_kB_CIS_up', 0.56666666666666665),
#  (u'CHR:Mammary Gland', u'NVS_NR_hPPARg', 1.0),
#  (u'CHR:Mammary Gland', u'APR_HepG2_StressKinase_1h_up', 0.59999999999999998),
#  (u'CHR:Pancreas', u'Tox21_AhR', 1.0),
#  (u'CHR:Pancreas', u'ATG_NF_kB_CIS_up', 0.72799999999999998),
#  (u'CHR:Pancreas', u'OT_ER_ERaERa_1440', 0.86399999999999999),
#  (u'CHR:Pancreas', u'APR_HepG2_CellLoss_24h_dn', 0.92800000000000005),
#  (u'CHR:Pancreas', u'APR_HepG2_CellCycleArrest_72h_dn', 0.97599999999999998),
#  (u'CHR:Pituitary Gland', u'Tox21_p53_BLA_p2_ratio', 0.62721893491124259),
#  (u'CHR:Pituitary Gland', u'ATG_BRE_CIS_up', 0.71597633136094674),
#  (u'CHR:Pituitary Gland', u'ATG_C_EBP_CIS_up', 1.0),
#  (u'CHR:Pituitary Gland', u'OT_FXR_FXRSRC1_0480', 0.67455621301775148),
#  (u'CHR:Pituitary Gland', u'BSK_BE3C_SRB_down', 0.65680473372781067),
#  (u'CHR:Spleen', u'APR_HepG2_CellLoss_24h_dn', 0.80700389105058368),
#  (u'CHR:Spleen', u'NVS_ENZ_rMAOAC', 0.86848249027237356),
#  (u'CHR:Spleen', u'APR_HepG2_MicrotubuleCSK_72h_up', 1.0),
#  (u'CHR:Spleen', u'NVS_NR_hER', 0.73151750972762641),
#  (u'CHR:Spleen', u'APR_HepG2_CellLoss_72h_dn', 0.68093385214007784),
#  (u'CHR:Stomach', u'ATG_PBREM_CIS_up', 1.0),
#  (u'CHR:Stomach', u'ATG_PXR_TRANS_up', 0.62318840579710144),
#  (u'CHR:Stomach', u'NVS_NR_hPPARg', 0.9503105590062112),
#  (u'CHR:Stomach', u'OT_ER_ERaERa_1440', 0.70186335403726707),
#  (u'CHR:Stomach', u'Tox21_TR_LUC_GH3_Agonist', 0.6045548654244306),
#  (u'CHR:Testes', u'Tox21_AR_BLA_Antagonist_ratio', 0.61463414634146341),
#  (u'CHR:Testes', u'OT_PPARg_PPARgSRC1_1440', 0.71317073170731704),
#  (u'CHR:Testes', u'ATG_PXRE_CIS_up', 0.52780487804878051),
#  (u'CHR:Testes', u'ATG_PPARg_TRANS_up', 1.0),
#  (u'CHR:Testes', u'NVS_MP_hPBR', 0.41463414634146339),
#  (u'CHR:Thymus', u'APR_HepG2_CellLoss_24h_dn', 0.55882352941176472),
#  (u'CHR:Thymus', u'APR_HepG2_StressKinase_1h_up', 1.0),
#  (u'CHR:Thymus', u'Tox21_MitochondrialToxicity_ratio', 0.62184873949579833),
#  (u'CHR:Thymus', u'ATG_PPARg_TRANS_up', 0.6386554621848739),
#  (u'CHR:Thymus', u'APR_HepG2_CellLoss_72h_dn', 0.3949579831932773),
#  (u'CHR:Thyroid Gland', u'ATG_C_EBP_CIS_up', 0.79126730564430248),
#  (u'CHR:Thyroid Gland', u'NVS_NR_hER', 1.0),
#  (u'CHR:Thyroid Gland', u'OT_ER_ERaERa_1440', 0.73908413205537804),
#  (u'CHR:Thyroid Gland',
#   u'APR_HepG2_OxidativeStress_72h_up',
#   0.69755058572949946),
#  (u'CHR:Thyroid Gland', u'ATG_PPARg_TRANS_up', 0.66666666666666663),
#  (u'CHR:Urinary Bladder', u'OT_PPARg_PPARgSRC1_1440', 0.68316831683168322),
#  (u'CHR:Urinary Bladder', u'ATG_CRE_CIS_up', 0.91089108910891092),
#  (u'CHR:Urinary Bladder', u'ATG_VDRE_CIS_up', 0.73267326732673266),
#  (u'CHR:Urinary Bladder',
#   u'APR_HepG2_MitoMembPot_24h_dn',
#   0.58415841584158412),
#  (u'CHR:Urinary Bladder', u'ATG_Oct_MLP_CIS_up', 1.0),
#  (u'CHR:Uterus', u'Tox21_AR_BLA_Antagonist_ratio', 1.0),
#  (u'CHR:Uterus', u'APR_HepG2_CellLoss_24h_dn', 0.63749999999999996),
#  (u'CHR:Uterus', u'BSK_3C_HLADR_down', 0.57999999999999996),
#  (u'CHR:Uterus', u'APR_HepG2_CellLoss_72h_dn', 0.54000000000000004),
#  (u'CHR:Uterus', u'ATG_CRE_CIS_up', 0.58750000000000002),
#  (u'MGR:Brain', u'ATG_SREBP_CIS_up', 0.94505494505494503),
#  (u'MGR:Brain', u'Tox21_MitochondrialToxicity_ratio', 0.94505494505494503),
#  (u'MGR:Brain', u'APR_HepG2_MicrotubuleCSK_72h_up', 0.8351648351648352),
#  (u'MGR:Brain', u'ATG_NFI_CIS_up', 0.61538461538461542),
#  (u'MGR:Brain', u'ATG_Oct_MLP_CIS_up', 1.0),
#  (u'MGR:Kidney', u'ATG_EGR_CIS_up', 0.72984749455337694),
#  (u'MGR:Kidney', u'ATG_VDRE_CIS_up', 1.0),
#  (u'MGR:Kidney', u'ACEA_T47D_80hr_Positive', 0.96514161220043571),
#  (u'MGR:Kidney', u'ATG_MRE_CIS_up', 0.72984749455337694),
#  (u'MGR:Kidney', u'Tox21_TR_LUC_GH3_Antagonist', 0.88888888888888884),
#  (u'MGR:Ovary', u'APR_HepG2_CellLoss_24h_dn', 0.78000000000000003),
#  (u'MGR:Ovary', u'ATG_BRE_CIS_up', 1.0),
#  (u'MGR:Ovary', u'Tox21_TR_LUC_GH3_Agonist', 0.67000000000000004),
#  (u'MGR:Ovary', u'ACEA_T47D_80hr_Positive', 0.67000000000000004),
#  (u'MGR:Ovary', u'ATG_CMV_CIS_up', 0.69999999999999996),
#  (u'MGR:Testes', u'OT_PPARg_PPARgSRC1_1440', 0.84999999999999998),
#  (u'MGR:Testes', u'APR_HepG2_StressKinase_1h_up', 0.85499999999999998),
#  (u'MGR:Testes', u'ATG_EGR_CIS_up', 0.77000000000000002),
#  (u'MGR:Testes', u'NVS_NR_hPPARg', 0.80500000000000005),
#  (u'MGR:Testes', u'ATG_Oct_MLP_CIS_up', 1.0),
#  (u'SUB:Adrenal Gland', u'APR_HepG2_StressKinase_1h_up', 0.6611165523996082),
#  (u'SUB:Adrenal Gland', u'ATG_MRE_CIS_up', 0.90695396669931438),
#  (u'SUB:Adrenal Gland', u'ATG_PXRE_CIS_up', 0.72771792360430954),
#  (u'SUB:Adrenal Gland', u'APR_HepG2_MitoMembPot_1h_dn', 1.0),
#  (u'SUB:Adrenal Gland', u'ATG_PPRE_CIS_up', 0.54946131243878549),
#  (u'SUB:Bone Marrow', u'APR_HepG2_CellLoss_24h_dn', 0.88505747126436785),
#  (u'SUB:Bone Marrow', u'ATG_CAR_TRANS_up', 1.0),
#  (u'SUB:Bone Marrow', u'APR_HepG2_CellLoss_72h_dn', 0.70881226053639845),
#  (u'SUB:Bone Marrow', u'APR_HepG2_StressKinase_1h_up', 0.56704980842911878),
#  (u'SUB:Bone Marrow', u'APR_HepG2_MitoMembPot_1h_dn', 0.6053639846743295),
#  (u'SUB:Brain', u'ATG_SREBP_CIS_up', 0.71816283924843427),
#  (u'SUB:Brain', u'Tox21_ERa_LUC_BG1_Agonist', 0.53235908141962418),
#  (u'SUB:Brain', u'NVS_NR_hER', 0.64509394572025047),
#  (u'SUB:Brain', u'ACEA_T47D_80hr_Positive', 0.49060542797494783),
#  (u'SUB:Brain', u'ATG_CMV_CIS_up', 1.0),
#  (u'SUB:Heart', u'ATG_SREBP_CIS_up', 0.20167286245353161),
#  (u'SUB:Heart', u'ATG_PPRE_CIS_up', 0.25278810408921931),
#  (u'SUB:Heart', u'NVS_NR_hER', 1.0),
#  (u'SUB:Heart', u'ATG_PPARg_TRANS_up', 0.20446096654275092),
#  (u'SUB:Heart', u'APR_HepG2_MitoMembPot_1h_dn', 0.2258364312267658),
#  (u'SUB:Kidney', u'APR_HepG2_StressKinase_1h_up', 0.52752293577981646),
#  (u'SUB:Kidney', u'ATG_EGR_CIS_up', 1.0),
#  (u'SUB:Kidney', u'OT_ER_ERbERb_0480', 0.47339449541284406),
#  (u'SUB:Kidney', u'ATG_ERE_CIS_up', 0.51284403669724765),
#  (u'SUB:Kidney', u'ATG_CAR_TRANS_up', 0.42752293577981654),
#  (u'SUB:Liver', u'ATG_BRE_CIS_up', 0.65912518853695323),
#  (u'SUB:Liver', u'ATG_PXRE_CIS_up', 1.0),
#  (u'SUB:Liver', u'NVS_NR_hER', 0.69683257918552033),
#  (u'SUB:Liver', u'OT_ER_ERaERa_1440', 0.69984917043740569),
#  (u'SUB:Liver', u'OT_ER_ERbERb_1440', 0.42081447963800905),
#  (u'SUB:Lung', u'ATG_SREBP_CIS_up', 0.67601246105919),
#  (u'SUB:Lung', u'APR_HepG2_StressKinase_1h_up', 1.0),
#  (u'SUB:Lung', u'OT_FXR_FXRSRC1_0480', 0.8909657320872274),
#  (u'SUB:Lung', u'ATG_PXR_TRANS_up', 0.77881619937694702),
#  (u'SUB:Lung', u'APR_HepG2_CellCycleArrest_72h_dn', 0.85046728971962615),
#  (u'SUB:Spleen', u'APR_HepG2_MitoMembPot_24h_dn', 0.65013054830287209),
#  (u'SUB:Spleen', u'ATG_CAR_TRANS_up', 0.51762402088772841),
#  (u'SUB:Spleen', u'NVS_NR_hER', 1.0),
#  (u'SUB:Spleen', u'OT_ER_ERaERa_1440', 0.92819843342036557),
#  (u'SUB:Spleen', u'Tox21_MitochondrialToxicity_ratio', 0.52284595300261094),
#  (u'SUB:Stomach', u'ATG_CRE_CIS_up', 0.91163793103448276),
#  (u'SUB:Stomach', u'ATG_PXR_TRANS_up', 1.0),
#  (u'SUB:Stomach', u'ATG_C_EBP_CIS_up', 0.87715517241379315),
#  (u'SUB:Stomach', u'ATG_Ahr_CIS_up', 0.83405172413793105),
#  (u'SUB:Stomach', u'ATG_PBREM_CIS_up', 0.71767241379310343),
#  (u'SUB:Testes', u'ATG_EGR_CIS_up', 0.18660287081339713),
#  (u'SUB:Testes', u'ATG_PXR_TRANS_up', 0.35406698564593303),
#  (u'SUB:Testes', u'ATG_ERE_CIS_up', 1.0),
#  (u'SUB:Testes', u'NVS_NR_hER', 0.16826156299840511),
#  (u'SUB:Testes', u'ACEA_T47D_80hr_Positive', 0.18979266347687401),
#  (u'SUB:Thymus', u'Tox21_ERa_LUC_BG1_Agonist', 0.67185289957567185),
#  (u'SUB:Thymus', u'NVS_MP_hPBR', 0.27298444130127297),
#  (u'SUB:Thymus', u'OT_ER_ERbERb_0480', 0.68175388967468176),
#  (u'SUB:Thymus', u'OT_ER_ERaERa_1440', 1.0),
#  (u'SUB:Thymus', u'ATG_CMV_CIS_up', 0.39179632248939178),
#  (u'SUB:Thyroid Gland', u'ATG_PXRE_CIS_up', 0.6207865168539326),
#  (u'SUB:Thyroid Gland', u'APR_HepG2_MitoMembPot_24h_dn', 1.0),
#  (u'SUB:Thyroid Gland', u'ATG_PPARg_TRANS_up', 0.5912921348314607),
#  (u'SUB:Thyroid Gland', u'APR_HepG2_MitoMembPot_1h_dn', 0.5997191011235955),
#  (u'SUB:Thyroid Gland', u'ATG_NRF2_ARE_CIS_up', 0.5730337078651685)]

# %%
C1 = TopBio2.ix[[i for i in Outcomes if i.startswith('SUB')]].corr(method='pearson')
C1[C1.abs()<0.7]=0

E2 = [(v1,v2,dict(f=C1.ix[v1,v2])) for v1 in C1.index for v2 in C1.columns if C1.ix[v1,v2]!=0 and v1!=v2]

len(E2)
# Out:
# 136

# %%
G1 = nx.Graph()
G1.add_edges_from(E1)
G1.add_edges_from(E2)

# %%
fig = pl.figure(figsize=(20,20))
ax = pl.subplot(1,1,1)
ax.set_axis_off()
NV0.G = G1
P=NV0.layout()

NV0.draw(alg='spring')

# %%
fig = pl.figure(figsize=(20,20))
ax = pl.subplot(1,1,1)
ax.set_axis_off()
NV0.G = G1
# Shells
S1 = Outcomes
Shells = [L for L in [[v for v,n in G1.degree().iteritems() if n==s and v not in S1] for s in range(5,0,-1)] if len(L)>0]
Sn = [v for v,n in G1.degree().iteritems() if n>5]
Shells = [Sn]+Shells+[S1]

P=NV0.layout(alg='shell',shells=Shells)
NV0.draw()
